# %%
Q1.  Explain with an example each when to use a for loop and a while loop. 
Ans- for loop is used to run a block of code for a certain number of times. It is used to iterate over any sequences such as list, tuple, string etc for example-
l = 'pwskills'
for i in l:
    print(i)
    
- With the while loop we can execute a set of statements as long as a condition is true example-
i = 1
while i < 10:
    print(i)
    i = i + 1
    
Q2.  Write a python program to print the sum and product of the first 10 natural numbers using for  and while loop. 
Ans- 
sum = 0
product = 1
for i in range (1,11):
    sum = sum + i
    product = product * i
    print('sum of first 10 natural number is :', sum)
    print('product of first 10 natural number is :', product)
    
    
sum = 0
product = 1
i = 1
while i <= 10:
    sum = sum + i
    product = product * i
    i = i + 1
    print('sum of first 10 natural numbers is :', sum)
    print('product of first 10 natural number is :', product)
    
Q3. Create a python program to compute the electricity bill for a household. 
The per-unit charges in rupees are as follows: For the first 100 units, the user will be charged Rs. 4.5 per  unit, for the next 100 units, the user will be charged Rs. 6 per unit, and for the next 100 units, the user will  be charged Rs. 10 per unit, After 300 units and above the user will be charged Rs. 20 per unit. 
You are required to take the units of electricity consumed in a month from the user as input. 
Your program must pass this test case: when the unit of electricity consumed by the user in a month is  310, the total electricity bill should be 2250. 
Ans- 

units = int(input('Enter the units consumed for electricity in a month'))
if units <= 100:
    bill = units * 4.5
    print(bill)
elif units <= 200:
    bill = (100*4.5) + ((units-100)*6)
    print(bill)
elif units <= 300:
    bill = (100*4.5) + (100*6) + ((units-100)*10)
    print(bill)
else:
    bill = (100*4.5) + (100*6) + (200*10) + ((units-100)*20)
    print(bill)


Q4. Create a list of numbers from 1 to 100. Use for loop and while loop to calculate the cube of each  number and if the cube of that number is divisible by 4 or 5 then append that number in a list and print  that list. 
Ans-
l = []
for i in range (1,101):
    if i**3%4==0 or i**3%5==0:
        l.append(i)
print(l)


l = []
i = 1
while i <= 100:
    if i**3%4==0 or i**3%5==0:
        l.append(i)
    i+=1
print(l)

Q5.  Write a program to filter count vowels in the below-given string. 
string = "I want to become a data scientist" 
Ans-

string = "I want to become a data scientist"
vowels = 0
consonants = 0
special_characters = 0
spaces = 0
digits = 0
alphabets = 0

for i in string:
    if i.isalpha():
        alphabets += 1
        if i in 'aeiouAEIOU':
            vowels += 1
        else:
            consonants += 1
    elif i.isdigit():
        digits += 1
    elif i.isspace():
        spaces += 1
    else:
        special_characters += 1

print("Vowels:", vowels)
print("Consonants:", consonants)
print("Special Characters:", special_characters)
print("Spaces:", spaces)
print("Digits:", digits)
print("Alphabets:", alphabets)
string = "I want to become a data scientist"
