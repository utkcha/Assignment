# %%
1. Write a program to accept percentage from the user and display the grade according to the following criteria: 
Marks       Grade 
>90           A 
>80 and <=90  B 
>=60 and <=80 C 
below 60      D 
Ans- 
Marks = int(input("Enter The Marks"))

if Marks > 90:
    print("Grade A")
elif Marks > 80 and Marks <= 90:
    print("Grade B")
elif Marks >= 60 and Marks <= 80:
    print("Grade C")
else:
    print("Grade D")
    
2. Write a program to accept the cost price of a bike and display the road tax to be paid according to the 
following criteria:
Tax     Cost Price(in Rs) 
15%     >100000 
10%     50000 and <= 100000 
5%      <= 50000  

Ans- 

CostPrice = int(input("Enter The CostPrice of bike in Rupees"))
if CostPrice > 100000:
    print("Need to Pay 15% tax")
elif CostPrice > 50000 and CostPrice <= 100000:
    print("Need to Pay 10% tax")
elif CostPrice <= 50000:
    print("Need to Pay 5% tax")

3. Accept any city from the user and display monuments of that city. 
City   Monument
Delhi  Red Fort  
Agra   Taj Mahal
Jaipur Jal Mahal 

Ans- 

city = input("Enter The City")
if city == 'delhi':
    print('Red Fort')
elif city == 'agra':
    print('Taj Mahal')
elif city == 'jaipur':
    print('Jal Mahal')
    
4. Check how many times a given number can be divided by 3 before it is less than or equal to 10. 
Ans- 

for i in l:
    if i%3==0:
        print("number is divided by 3 is",i)
        i+1
        i<=10
        
5. Why and When to Use while Loop in Python give a detailed description with example.
Ans- A while loop evaluates the condition. If the condition evaluates to True , the code inside the while loop is executed.
example-  
i = 1
while i<10:
print(i)
i+1

6. use nested while loop to print 3 different patterns.
Ans-
n = int(input('Enter number of rows :'))

i = 1
while i <= n:
    j = 1
    while j <= i:
        print ('*', end = ' ')
        j += 1
    print()
    i += 1
        
        
        
n = int(input('Enter the number of rows :'))

i = 1
while i <= n:
    j = n
    while j >= i:
        print('*', end =' ')
        j -= 1
    print()
    i += 1

    
n = int(input('Enter the number of rows :'))

k = 1
i = 1
while i <= n:
    j = 1
    while j <= i:
        print("{:3d}".format(k), end = " ")
        j += 1
        k += 1
    print()
    i += 1
    
7. reverse a while loop to display numbers from 10 to 1.
Ans-
i = 10
while i > 0:
    print(i)
    i - 1
